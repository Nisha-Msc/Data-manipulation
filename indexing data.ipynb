# %%
import pandas as pd
import numpy as np

# %% [markdown]
# INDEXING THE PANDAS

# %%
df = pd.read_csv(r"C:\Users\Administrator\Downloads\world_population.csv", encoding='ISO-8859-1')
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df = pd.read_csv(r"C:\Users\Administrator\Downloads\world_population.csv", encoding='ISO-8859-1',index_col="Country/Territory")
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country/Territory
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH         El AaiÃºn    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#      Country/Territory  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH         El AaiÃºn    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.set_index('Capital',inplace = True)
df
# Out:
#                   Rank CCA3 Continent  2022 Population  2020 Population  \
# Capital
# Kabul               36  AFG      Asia         41128771         38972230
# Tirana             138  ALB    Europe          2842321          2866849
# Algiers             34  DZA    Africa         44903225         43451666
# Pago Pago          213  ASM   Oceania            44273            46189
# Andorra la Vella   203  AND    Europe            79824            77700
# ...                ...  ...       ...              ...              ...
# Mata-Utu           226  WLF   Oceania            11572            11655
# El AaiÃºn          172  ESH    Africa           575986           556048
# Sanaa               46  YEM      Asia         33696614         32284046
# Lusaka              63  ZMB    Africa         20017675         18927715
# Harare              74  ZWE    Africa         16320537         15669666
#
#                   2015 Population  2010 Population  2000 Population  \
# Capital
# ...

# %%
df.loc['Kabul']
# Out:
# Rank                                 36
# CCA3                                AFG
# Continent                          Asia
# 2022 Population                41128771
# 2020 Population                38972230
# 2015 Population                33753499
# 2010 Population                28189672
# 2000 Population                19542982
# 1990 Population                10694796
# 1980 Population                12486631
# 1970 Population                10752971
# Area (kmÂ²)                      652230
# Density (per kmÂ²)              63.0587
# Growth Rate                      1.0257
# World Population Percentage        0.52
# Name: Kabul, dtype: object

# %%
df.iloc[0]
# Out:
# Rank                                 36
# CCA3                                AFG
# Continent                          Asia
# 2022 Population                41128771
# 2020 Population                38972230
# 2015 Population                33753499
# 2010 Population                28189672
# 2000 Population                19542982
# 1990 Population                10694796
# 1980 Population                12486631
# 1970 Population                10752971
# Area (kmÂ²)                      652230
# Density (per kmÂ²)              63.0587
# Growth Rate                      1.0257
# World Population Percentage        0.52
# Name: Kabul, dtype: object

# %%
df
# Out:
#                   Rank CCA3 Continent  2022 Population  2020 Population  \
# Capital
# Kabul               36  AFG      Asia         41128771         38972230
# Tirana             138  ALB    Europe          2842321          2866849
# Algiers             34  DZA    Africa         44903225         43451666
# Pago Pago          213  ASM   Oceania            44273            46189
# Andorra la Vella   203  AND    Europe            79824            77700
# ...                ...  ...       ...              ...              ...
# Mata-Utu           226  WLF   Oceania            11572            11655
# El AaiÃºn          172  ESH    Africa           575986           556048
# Sanaa               46  YEM      Asia         33696614         32284046
# Lusaka              63  ZMB    Africa         20017675         18927715
# Harare              74  ZWE    Africa         16320537         15669666
#
#                   2015 Population  2010 Population  2000 Population  \
# Capital
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#               Capital  Rank CCA3 Continent  2022 Population  2020 Population  \
# 0               Kabul    36  AFG      Asia         41128771         38972230
# 1              Tirana   138  ALB    Europe          2842321          2866849
# 2             Algiers    34  DZA    Africa         44903225         43451666
# 3           Pago Pago   213  ASM   Oceania            44273            46189
# 4    Andorra la Vella   203  AND    Europe            79824            77700
# ..                ...   ...  ...       ...              ...              ...
# 229          Mata-Utu   226  WLF   Oceania            11572            11655
# 230         El AaiÃºn   172  ESH    Africa           575986           556048
# 231             Sanaa    46  YEM      Asia         33696614         32284046
# 232            Lusaka    63  ZMB    Africa         20017675         18927715
# 233            Harare    74  ZWE    Africa         16320537         15669666
#
# ...

# %%
df.set_index(['Capital','Continent'],inplace = True)
df
# Out:
#                             Rank CCA3  2022 Population  2020 Population  \
# Capital          Continent
# Kabul            Asia         36  AFG         41128771         38972230
# Tirana           Europe      138  ALB          2842321          2866849
# Algiers          Africa       34  DZA         44903225         43451666
# Pago Pago        Oceania     213  ASM            44273            46189
# Andorra la Vella Europe      203  AND            79824            77700
# ...                          ...  ...              ...              ...
# Mata-Utu         Oceania     226  WLF            11572            11655
# El AaiÃºn        Africa      172  ESH           575986           556048
# Sanaa            Asia         46  YEM         33696614         32284046
# Lusaka           Africa       63  ZMB         20017675         18927715
# Harare           Africa       74  ZWE         16320537         15669666
#
# ...

# %%
df.sort_index(ascending= [True])
# Out:
#                         Rank CCA3  2022 Population  2020 Population  \
# Capital      Continent
# Abu Dhabi    Asia         97  ARE          9441129          9287289
# Abuja        Africa        6  NGA        218541212        208327405
# Accra        Africa       47  GHA         33475870         32180401
# Addis Ababa  Africa       12  ETH        123379924        117190911
# Algiers      Africa       34  DZA         44903225         43451666
# ...                      ...  ...              ...              ...
# Yamoussoukro Africa       52  CIV         28160542         26811790
# Yaounde      Africa       53  CMR         27914536         26491087
# Yaren        Oceania     225  NRU            12668            12315
# Yerevan      Asia        140  ARM          2780469          2805608
# Zagreb       Europe      130  HRV          4030358          4096868
#
#                         2015 Population  2010 Population  2000 Population  \
# Capital      Continent
# ...
